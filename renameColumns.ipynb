# %%
import pandas as pd

# Define the mapping dictionary
acs_variable_mapping = {
    'B27001_001E': 'Total: Health Insurance Coverage Status by Sex by Age',
    'B27001_002E': 'Total: Male',
    'B27001_003E': 'Total: Male: Under 6 years',
    'B27001_004E': 'Total: Male: Under 6 years: With health insurance coverage',
    'B27001_005E': 'Total: Male: Under 6 years: No health insurance coverage',
    'B27001_006E': 'Total: Male: 6 to 18 years',
    'B27001_007E': 'Total: Male: 6 to 18 years: With health insurance coverage',
    'B27001_008E': 'Total: Male: 6 to 18 years: No health insurance coverage',
    'B27001_009E': 'Total: Male: 19 to 25 years',
    'B27001_010E': 'Total: Male: 19 to 25 years: With health insurance coverage',
    'B27001_011E': 'Total: Male: 19 to 25 years: No health insurance coverage',
    'B27001_012E': 'Total: Male: 26 to 34 years',
    'B27001_013E': 'Total: Male: 26 to 34 years: With health insurance coverage',
    'B27001_014E': 'Total: Male: 26 to 34 years: No health insurance coverage',
    'B27001_015E': 'Total: Male: 35 to 44 years',
    'B27001_016E': 'Total: Male: 35 to 44 years: With health insurance coverage',
    'B27001_017E': 'Total: Male: 35 to 44 years: No health insurance coverage',
    'B27001_018E': 'Total: Male: 45 to 54 years',
    'B27001_019E': 'Total: Male: 45 to 54 years: With health insurance coverage',
    'B27001_020E': 'Total: Male: 45 to 54 years: No health insurance coverage',
    'B27001_021E': 'Total: Male: 55 to 64 years',
    'B27001_022E': 'Total: Male: 55 to 64 years: With health insurance coverage',
    'B27001_023E': 'Total: Male: 55 to 64 years: No health insurance coverage',
    'B27001_024E': 'Total: Male: 65 to 74 years',
    'B27001_025E': 'Total: Male: 65 to 74 years: With health insurance coverage',
    'B27001_026E': 'Total: Male: 65 to 74 years: No health insurance coverage',
    'B27001_027E': 'Total: Male: 75 years and over',
    'B27001_028E': 'Total: Male: 75 years and over: With health insurance coverage',
    'B27001_029E': 'Total: Male: 75 years and over: No health insurance coverage',
    'B27001_030E': 'Total: Female',
    'B27001_031E': 'Total: Female: Under 6 years',
    'B27001_032E': 'Total: Female: Under 6 years: With health insurance coverage',
    'B27001_033E': 'Total: Female: Under 6 years: No health insurance coverage',
    'B27001_034E': 'Total: Female: 6 to 18 years',
    'B27001_035E': 'Total: Female: 6 to 18 years: With health insurance coverage',
    'B27001_036E': 'Total: Female: 6 to 18 years: No health insurance coverage',
    'B27001_037E': 'Total: Female: 19 to 25 years',
    'B27001_038E': 'Total: Female: 19 to 25 years: With health insurance coverage',
    'B27001_039E': 'Total: Female: 19 to 25 years: No health insurance coverage',
    'B27001_040E': 'Total: Female: 26 to 34 years',
    'B27001_041E': 'Total: Female: 26 to 34 years: With health insurance coverage',
    'B27001_042E': 'Total: Female: 26 to 34 years: No health insurance coverage',
    'B27001_043E': 'Total: Female: 35 to 44 years',
    'B27001_044E': 'Total: Female: 35 to 44 years: With health insurance coverage',
    'B27001_045E': 'Total: Female: 35 to 44 years: No health insurance coverage',
    'B27001_046E': 'Total: Female: 45 to 54 years',
    'B27001_047E': 'Total: Female: 45 to 54 years: With health insurance coverage',
    'B27001_048E': 'Total: Female: 45 to 54 years: No health insurance coverage',
    'B27001_049E': 'Total: Female: 55 to 64 years',
    'B27001_050E': 'Total: Female: 55 to 64 years: With health insurance coverage',
    'B27001_051E': 'Total: Female: 55 to 64 years: No health insurance coverage',
    'B27001_052E': 'Total: Female: 65 to 74 years',
    'B27001_053E': 'Total: Female: 65 to 74 years: With health insurance coverage',
    'B27001_054E': 'Total: Female: 65 to 74 years: No health insurance coverage',
    'B27001_055E': 'Total: Female: 75 years and over',
    'B27001_056E': 'Total: Female: 75 years and over: With health insurance coverage',
    'B27001_057E': 'Total: Female: 75 years and over: No health insurance coverage'
}


# Function to rename columns in a DataFrame
def rename_acs_columns(df):
    return df.rename(columns=acs_variable_mapping)

# Example usage:
df = pd.read_csv("C:/Users/amyyy/OneDrive/Desktop/MATH_537/FINALPROJ/Data/SDOHRawData/combined_county_data1.csv")
df = rename_acs_columns(df)
df.to_csv("C:/Users/amyyy/OneDrive/Desktop/MATH_537/FINALPROJ/Data/combined_county_data3.csv")
